# %%
import pandas as pd
df=pd.read_csv("insurance_churn.csv")
display(df)
# Out:
#      customer_id  age  gender  tenure_months  monthly_premium  \
# 0    CUST_001672   70  Female            178           222.37
# 1    CUST_007800   53  Female            139           746.88
# 2    CUST_002614   32  Female            205          1282.70
# 3    CUST_003411   24  Female              4          2210.51
# 4    CUST_010302   26    Male            143          1654.00
# ..           ...  ...     ...            ...              ...
# 995  CUST_005918   59  Female             37          3506.01
# 996  CUST_001008   64  Female            143          3107.79
# 997  CUST_001404   46    Male            145           210.49
# 998  CUST_011984   56  Female             74           860.16
# 999  CUST_002643   25  Female            220          2247.18
#
#      past_claims_count  missed_payments_12m  risk_score  churn_flag
# 0                    0                    1        70.0           0
# 1                    2                    0        74.0           0
# ...

# %%
df_highriskscore = df[df['risk_score']>=70]
display(df_highriskscore)
# Out:
#      customer_id  age  gender  tenure_months  monthly_premium  \
# 0    CUST_001672   70  Female            178           222.37
# 1    CUST_007800   53  Female            139           746.88
# 7    CUST_007579   61  Female            120           746.57
# 9    CUST_006364   48  Female             27          3196.38
# 13   CUST_010129   58  Female              9           355.04
# ..           ...  ...     ...            ...              ...
# 964  CUST_010154   68  Female             98          3389.15
# 969  CUST_011993   74    Male             25          2872.96
# 970  CUST_001708   73    Male             50           607.64
# 981  CUST_002495   70  Female             58          2354.92
# 987  CUST_000647   70  Female             58          2354.62
#
#      past_claims_count  missed_payments_12m  risk_score  churn_flag
# 0                    0                    1        70.0           0
# 1                    2                    0        74.0           0
# ...
