# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the dataset
df = pd.read_csv('insurance.csv')

# Configure plot styles for better visibility
sns.set_theme(style="whitegrid")
print("Libraries imported and data loaded.")
# Out:
# Libraries imported and data loaded.

# %%
# %pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=1.2 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the dataset
df = pd.read_csv('insurance.csv')

# Set visual style
sns.set_theme(style="whitegrid")
print("Data loaded successfully!")
df.head()
# Out:
# Data loaded successfully!
#    customer_id  age  gender   income_band employment_status       province  \
# 0  CUST_001935   71    Male  Upper-Middle     Self-Employed     North West
# 1  CUST_006494   49  Female        Middle     Self-Employed  KwaZulu-Natal
# 2  CUST_001720   51  Female        Middle          Employed   Western Cape
# 3  CUST_009120   32    Male  Lower-Middle          Employed   Eastern Cape
# 4  CUST_000360   33  Female  Lower-Middle        Unemployed        Gauteng
#
#   urban_rural  household_size  province_risk_score        policy_type  ...  \
# 0       Urban               6                 0.26           Accident  ...
# 1       Urban               4                 0.18               COID  ...
# 2       Rural               5                 0.15           Accident  ...
# 3       Urban               2                 0.25            Funeral  ...
# 4       Rural               1                 0.20  Income Protection  ...
#
#    funeral_policy_flag  high_amount_flag  fraud_flag  loss_ratio  \
# 0                    0                 0           0        0.00
# 1                    0                 0           0        0.57
# 2                    0                 0           0        0.00
# 3                    1                 0           0        0.79
# 4                    0                 0           0        1.25
#
#    pricing_adequacy_flag churn_probability churn_flag  retention_score  \
# 0                      1            0.0600          0            0.940
# 1                      1            0.2595          0            0.740
# 2                      1            0.0600          0            0.940
# 3                      1            0.3365          1            0.664
# 4                      0            0.4975          1            0.502
#
#   upgrade_flag  customer_lifetime_value
# 0            1                127780.50
# 1            0                174398.72
# 2            0                136722.26
# 3            0                114347.43
# 4            0                 36080.55
#
# [5 rows x 53 columns]

# %%
print("--- Column Information ---")
df.info()

print("\n--- Missing Values ---")
print(df.isnull().sum())

print("\n--- Statistical Summary ---")
df.describe()
# Out:
# --- Column Information ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9600 entries, 0 to 9599
# Data columns (total 53 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_id              9600 non-null   object
#  1   age                      9600 non-null   int64
#  2   gender                   9600 non-null   object
#  3   income_band              9600 non-null   object
#  4   employment_status        9600 non-null   object
#  5   province                 9600 non-null   object
#  6   urban_rural              9600 non-null   object
#  7   household_size           9600 non-null   int64
#  8   province_risk_score      9600 non-null   float64
#  9   policy_type              9600 non-null   object
#  10  tenure_months            9600 non-null   int64
#  11  num_active_policies      9600 non-null   int64
#  12  sum_assured              9600 non-null   float64
#  13  monthly_premium          9600 non-null   float64
#  14  expected_annual_premium  9600 non-null   float64
#  15  employer_id              9600 non-null   object
#  16  industry_type            9600 non-null   object
#  17  num_employees            9600 non-null   int64
#  18  location                 9600 non-null   object
#  19  safety_score             9600 non-null   int64
#  20  coverage_type            9600 non-null   object
#  21  deductible               9600 non-null   float64
#  22  policy_age_months        9600 non-null   int64
#  23  job_role                 9600 non-null   object
#  24  employee_age             9600 non-null   int64
#  25  health_score             9600 non-null   int64
#  26  risk_score               9600 non-null   float64
#  27  risk_level               9600 non-null   object
#  28  past_claims_count        9600 non-null   int64
#  29  past_claims_amount       9600 non-null   float64
#  30  expected_loss            9600 non-null   float64
#  31  premium_recommendation   9600 non-null   float64
#  32  payment_method           9600 non-null   object
#  33  debit_order_flag         9600 non-null   int64
#  34  missed_payments_12m      9600 non-null   int64
#  35  lapse_flag               9600 non-null   int64
#  36  claims_count_12m         9600 non-null   int64
#  37  claim_frequency_12m      9600 non-null   float64
#  38  total_claim_amount_12m   9600 non-null   float64
#  39  avg_claim_amount_12m     9600 non-null   float64
#  40  repeat_submission_flag   9600 non-null   int64
#  41  submission_delay_days    9600 non-null   int64
#  42  late_submission_flag     9600 non-null   int64
#  43  funeral_policy_flag      9600 non-null   int64
#  44  high_amount_flag         9600 non-null   int64
#  45  fraud_flag               9600 non-null   int64
#  46  loss_ratio               9600 non-null   float64
#  47  pricing_adequacy_flag    9600 non-null   int64
#  48  churn_probability        9600 non-null   float64
#  49  churn_flag               9600 non-null   int64
#  50  retention_score          9600 non-null   float64
#  51  upgrade_flag             9600 non-null   int64
#  52  customer_lifetime_value  9600 non-null   float64
# dtypes: float64(16), int64(23), object(14)
# memory usage: 3.9+ MB
#
# --- Missing Values ---
# customer_id                0
# age                        0
# gender                     0
# income_band                0
# employment_status          0
# province                   0
# urban_rural                0
# household_size             0
# province_risk_score        0
# policy_type                0
# tenure_months              0
# num_active_policies        0
# sum_assured                0
# monthly_premium            0
# expected_annual_premium    0
# employer_id                0
# industry_type              0
# num_employees              0
# location                   0
# safety_score               0
# coverage_type              0
# deductible                 0
# policy_age_months          0
# job_role                   0
# employee_age               0
# health_score               0
# risk_score                 0
# risk_level                 0
# past_claims_count          0
# past_claims_amount         0
# expected_loss              0
# premium_recommendation     0
# payment_method             0
# debit_order_flag           0
# missed_payments_12m        0
# lapse_flag                 0
# claims_count_12m           0
# claim_frequency_12m        0
# total_claim_amount_12m     0
# avg_claim_amount_12m       0
# repeat_submission_flag     0
# submission_delay_days      0
# late_submission_flag       0
# funeral_policy_flag        0
# high_amount_flag           0
# fraud_flag                 0
# loss_ratio                 0
# pricing_adequacy_flag      0
# churn_probability          0
# churn_flag                 0
# retention_score            0
# upgrade_flag               0
# customer_lifetime_value    0
# dtype: int64
#
# --- Statistical Summary ---
#                age  household_size  province_risk_score  tenure_months  \
# count  9600.000000     9600.000000          9600.000000    9600.000000
# mean     46.115104        3.489583             0.211773     121.084792
# std      16.352342        1.713910             0.046307      68.950699
# min      18.000000        1.000000             0.150000       1.000000
# 25%      32.000000        2.000000             0.180000      61.750000
# 50%      46.000000        3.000000             0.200000     122.000000
# 75%      60.000000        5.000000             0.250000     181.000000
# max      74.000000        6.000000             0.300000     239.000000
#
#        num_active_policies    sum_assured  monthly_premium  \
# count          9600.000000    9600.000000      9600.000000
# mean              1.996771  261087.369230      1464.284847
# std               0.817362  138552.723934       899.545021
# min               1.000000   20109.870000        72.630000
# 25%               1.000000  140186.392500       736.267500
# 50%               2.000000  263097.940000      1357.830000
# 75%               3.000000  380172.590000      2058.925000
# max               3.000000  499960.140000      4707.630000
#
#        expected_annual_premium  num_employees  safety_score  ...  \
# count              9600.000000    9600.000000   9600.000000  ...
# mean              17571.418163     104.653333     75.063333  ...
# std               10794.540255      55.170548     14.545192  ...
# min                 871.560000      10.000000     50.000000  ...
# 25%                8835.210000      57.000000     63.000000  ...
# 50%               16293.960000     104.000000     75.000000  ...
# 75%               24707.100000     153.000000     88.000000  ...
# max               56491.560000     199.000000     99.000000  ...
#
#        funeral_policy_flag  high_amount_flag   fraud_flag   loss_ratio  \
# count          9600.000000       9600.000000  9600.000000  9600.000000
# mean              0.301667          0.029375     0.129792     1.312639
# std               0.459005          0.168864     0.336092     3.374033
# min               0.000000          0.000000     0.000000     0.000000
# 25%               0.000000          0.000000     0.000000     0.000000
# 50%               0.000000          0.000000     0.000000     0.000000
# 75%               1.000000          0.000000     0.000000     1.290000
# max               1.000000          1.000000     1.000000    83.360000
#
#        pricing_adequacy_flag  churn_probability   churn_flag  retention_score  \
# count            9600.000000        9600.000000  9600.000000      9600.000000
# mean                0.705833           0.314087     0.316146         0.685934
# std                 0.455691           0.318025     0.464995         0.318010
# min                 0.000000           0.060000     0.000000         0.100000
# 25%                 0.000000           0.060000     0.000000         0.471000
# 50%                 1.000000           0.179000     0.000000         0.821000
# 75%                 1.000000           0.529000     1.000000         0.940000
# max                 1.000000           0.900000     1.000000         0.940000
#
#        upgrade_flag  customer_lifetime_value
# count   9600.000000              9600.000000
# mean       0.152604             83227.618701
# std        0.359624             73852.969009
# min        0.000000               447.290000
# 25%        0.000000             22441.412500
# 50%        0.000000             66576.875000
# 75%        0.000000            122856.195000
# max        1.000000            484045.730000
#
# [8 rows x 39 columns]

# %%
plt.figure(figsize=(10, 6))
# Histogram of risk scores colored by churn status
sns.histplot(data=df, x='risk_score', hue='churn_flag', kde=True, bins=30)

# Vertical line at your threshold
plt.axvline(70, color='red', linestyle='--', label='Threshold (60)')
plt.title('Risk Score Distribution: Churn vs. Non-Churn')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 8))

numeric_df = df.select_dtypes(include=[np.number])
corr = numeric_df.corr()

sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Tenure vs Churn
sns.boxplot(ax=axes[0], x='churn_flag', y='tenure_months', data=df)
axes[0].set_title('Customer Tenure vs. Churn')

# Monthly Premium vs Churn
sns.boxplot(ax=axes[1], x='churn_flag', y='monthly_premium', data=df)
axes[1].set_title('Monthly Premium vs. Churn')

plt.show()

# %%
# Churn rate by Gender
gender_plot = pd.crosstab(df['gender'], df['churn_flag'], normalize='index')
gender_plot.plot(kind='bar', stacked=True, color=['skyblue', 'salmon'], figsize=(8,5))

plt.title('Churn Rate by Gender')
plt.ylabel('Proportion')
plt.xlabel('Gender')
plt.xticks(rotation=0)
plt.legend(title='Churned', labels=['No', 'Yes'])
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='missed_payments_12m', hue='churn_flag')
plt.title('Impact of Missed Payments on Churn')
plt.xlabel('Missed Payments in Last 12 Months')
plt.show()

# %%
import shutil
import os

folder = 'outputs'

if os.path.exists(folder):
    # Remove the folder and all its contents
    shutil.rmtree(folder)
    # Re-create the empty folder
    os.makedirs(folder)
    print(f"✅ All files in '{folder}' have been deleted.")
else:
    os.makedirs(folder)
    print(f"Created new '{folder}' folder.")
# Out:
# ✅ All files in 'outputs' have been deleted.

# %%
from azure.ai.ml import MLClient
from azure.ai.ml.entities import Model
from azure.ai.ml.constants import AssetTypes
from azure.identity import DefaultAzureCredential

# 1. Connect to Azure ML
ml_client = MLClient.from_config(DefaultAzureCredential())

# 2. Register the 'tuned_balanced_model.pkl' you just created
run_model = Model(
    path="outputs/tuned_balanced_model.pkl", 
    name="insurance-churn-model",
    version="1",
    description="Balanced Random Forest with n_estimators=300, depth=4",
    type=AssetTypes.CUSTOM_MODEL
)

print("Registering model in Azure ML...")
ml_client.models.create_or_update(run_model)
print(" Model registered! You can now see it in the 'Models' tab.")
# Out:
# Found the config file in: /config.json
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Uploading tuned_balanced_model.pkl (< 1 MB): 100%|██████████| 3.84M/3.84M [00:00<00:00, 31.8MB/s]
# Registering model in Azure ML...
#  Model registered! You can now see it in the 'Models' tab.
